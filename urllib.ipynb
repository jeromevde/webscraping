# %% [markdown]
# # Simplest scraping

# %%
from urllib.request import urlopen

html = urlopen("https://fr.wikipedia.org/wiki/Club_de_football").read().decode('utf-8')
print(html)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="fr" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Club de football — Wikipédia</title>
# ...

# %% [markdown]
# **Then we select some text according to the tag arround text using regular expression**

# %%
import re
res = re.findall(r"<title>(.+?)</title>", html)
print("\nPage title is: ", res[0])
# Out:
# Page title is:  Club de football — Wikipédia

# %% [markdown]
# **And select links using regex**

# %%
res = re.findall(r'href="(.*?)"', html)
print("\nAll links: ", res)
# Out:
# All links:  ['/w/load.php?lang=fr&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.ui.button%2Cicon%7Cskins.vector.icons%2Cstyles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector', '/w/load.php?lang=fr&amp;modules=site.styles&amp;only=styles&amp;skin=vector', '//upload.wikimedia.org', '//fr.m.wikipedia.org/wiki/Club_de_football', '/w/index.php?title=Club_de_football&amp;action=edit', '/w/index.php?title=Club_de_football&amp;action=edit', '/static/apple-touch/wikipedia.png', '/static/favicon/wikipedia.ico', '/w/opensearch_desc.php', '//fr.wikipedia.org/w/api.php?action=rsd', '//creativecommons.org/licenses/by-sa/3.0/', 'https://fr.wikipedia.org/wiki/Club_de_football', '//login.wikimedia.org', '//meta.wikimedia.org', '#content', '/wiki/Wikip%C3%A9dia:Accueil_principal', '/wiki/Sp%C3%A9cial:Mes_discussions', '/wiki/Sp%C3%A9cial:Mes_contributions', '/w/index.php?title=Sp%C3%A9cial:Cr%C3%A9er_un_co
# ...
